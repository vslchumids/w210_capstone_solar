# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12.0, 6.0)

import numpy as np
import math
import sys
import subprocess
import seaborn as sns
from fbprophet import Prophet

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

pd.set_option('display.float_format', lambda x: '%.5f' % x) # pandas
np.set_printoptions(precision=5, suppress=True) # numpy

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# seaborn plotting style
sns.set(style='ticks', context='poster')

# %%
station_cls = pd.read_csv('station_cluster.csv')
station_cls.head()
# Out:
#    Unnamed: 0                    Station  Cluster      Lat       Long  \
# 0           0           CARLSBAD/PALOMAR       11 33.13300 -117.28300
# 1           1  SACRAMENTO EXECUTIVE ARPT        3 38.50000 -121.50000
# 2           2                TUSTIN MCAF        2 33.70000 -117.83300
# 3           3               MATHER FIELD       13 38.55000 -121.30000
# 4           4     REDDING MUNICIPAL ARPT        9 40.51700 -122.31700
#
#    Centroid_Dist
# 0        2.54477
# 1        3.01334
# 2        4.67815
# 3        2.03201
# 4        2.85041

# %%
ca_meta = pd.read_csv('CA_weather_stations.csv')
ca_meta.head()
# Out:
#    Unnamed: 0    USAF           STATION  CLASS  latitude  longitude
# 0           0  690140      EL TORO MCAS      3  33.66700 -117.73300
# 1           1  690150  TWENTYNINE PALMS      2  34.30000 -116.16700
# 2           2  690160       TUSTIN MCAF      3  33.70000 -117.83300
# 3         363  722810               NAF      3  32.81700 -115.68300
# 4         364  722860         MARCH AFB      2  33.90000 -117.25000

# %%
stations = pd.merge(station_cls, ca_meta, left_on='Station', right_on='STATION')

# %%
stations.head()
# Out:
#    Unnamed: 0_x                    Station  Cluster      Lat       Long  \
# 0             0           CARLSBAD/PALOMAR       11 33.13300 -117.28300
# 1             1  SACRAMENTO EXECUTIVE ARPT        3 38.50000 -121.50000
# 2             2                TUSTIN MCAF        2 33.70000 -117.83300
# 3             3               MATHER FIELD       13 38.55000 -121.30000
# 4             4     REDDING MUNICIPAL ARPT        9 40.51700 -122.31700
#
#    Centroid_Dist  Unnamed: 0_y    USAF                    STATION  CLASS  \
# 0        2.54477           386  722927           CARLSBAD/PALOMAR      2
# 1        3.01334           757  724830  SACRAMENTO EXECUTIVE ARPT      1
# 2        4.67815             2  690160                TUSTIN MCAF      3
# 3        2.03201           758  724833               MATHER FIELD      3
# 4        2.85041          1045  725920     REDDING MUNICIPAL ARPT      1
#
#    latitude  longitude
# 0  33.13300 -117.28300
# 1  38.50000 -121.50000
# 2  33.70000 -117.83300
# 3  38.55000 -121.30000
# 4  40.51700 -122.31700

# %%
stations.drop(columns=['Unnamed: 0_x', 'STATION', 'latitude', 'longitude', 'Unnamed: 0_y'], inplace=True)
stations.head()
# Out:
#                      Station  Cluster      Lat       Long  Centroid_Dist  \
# 0           CARLSBAD/PALOMAR       11 33.13300 -117.28300        2.54477
# 1  SACRAMENTO EXECUTIVE ARPT        3 38.50000 -121.50000        3.01334
# 2                TUSTIN MCAF        2 33.70000 -117.83300        4.67815
# 3               MATHER FIELD       13 38.55000 -121.30000        2.03201
# 4     REDDING MUNICIPAL ARPT        9 40.51700 -122.31700        2.85041
#
#      USAF  CLASS
# 0  722927      2
# 1  724830      1
# 2  690160      3
# 3  724833      3
# 4  725920      1

# %%
stations
# Out:
#                            Station  Cluster      Lat       Long  \
# 0                 CARLSBAD/PALOMAR        2 33.13300 -117.28300
# 1        SACRAMENTO EXECUTIVE ARPT        3 38.50000 -121.50000
# 2                      TUSTIN MCAF        2 33.70000 -117.83300
# 3                     MATHER FIELD        3 38.55000 -121.30000
# 4           REDDING MUNICIPAL ARPT        5 40.51700 -122.31700
# 5         HANFORD MUNI ARPT [ISIS]        3 36.31000 -119.63000
# 6                    CHINO AIRPORT        0 33.96700 -117.63300
# 7               LEMOORE REEVES NAS        3 36.33300 -119.95000
# 8       PASO ROBLES MUNICIPAL ARPT        3 35.66700 -120.63300
# 9          FRESNO YOSEMITE INTL AP        3 36.78300 -119.71700
# 10      SACRAMENTO METROPOLITAN AP        3 38.70000 -121.58300
# 11                TRAVIS FIELD AFB        4 38.26700 -121.93300
# 12                CAMARILLO (AWOS)        3 34.21700 -119.08300
# 13                VAN NUYS AIRPORT        2 34.21700 -118.48300
# 14                    BEAUMONT 1 E        0 33.93300 -116.96700
# 15                          MOJAVE        5 35.06700 -118.15000
# 16             SAN NICHOLAS ISLAND        3 33.25000 -119.45000
# 17            SAN CLEMENTE IS NAAS        2 33.01700 -118.58300
# 18        LONG BEACH DAUGHERTY FLD        2 33.83300 -118.16700
# 19               PALM SPRINGS INTL        0 33.83300 -116.50000
# 20                        SANDBERG        5 34.75000 -118.71700
# 21            SALINAS MUNICIPAL AP        4 36.66700 -121.60000
# 22                             NAF        6 32.81700 -115.68300
# 23   CONCORD CONCORD-BUCHANAN FIEL        4 38.00000 -122.05000
# 24                SOUTH LAKE TAHOE        1 38.90000 -120.00000
# 25           SAN FRANCISCO INTL AP        4 37.61700 -122.40000
# 26             NORTON AFB/SAN BERN        0 34.10000 -117.23300
# 27                  ARCATA AIRPORT        4 40.98300 -124.10000
# 28        RED BLUFF MUNICIPAL ARPT        3 40.15000 -122.25000
# 29                 CHICO MUNICIPAL        3 39.80000 -121.85000
# 30                   MCCLELLAN AFB        3 38.66700 -121.40000
# 31              BICYCLE LAKE (AAF)        5 35.28300 -116.61700
# 32                          MADERA        3 36.98300 -120.11700
# 33             LIVERMORE MUNICIPAL        4 37.70000 -121.81700
# 34                  VANDENBERG AFB        4 34.75000 -120.58300
# 35           SAN DIEGO MIRAMAR NAS        2 32.86700 -117.13300
# 36             SAN DIEGO/MONTGOMER        2 32.81700 -117.13300
# 37             MERCED/MACREADY FLD        3 37.28300 -120.51700
# 38                         ALTURAS        1 41.50000 -120.53300
# 39              VACAVILLE NUT TREE        4 38.36700 -121.95000
# 40                     WATSONVILLE        4 36.93300 -121.78300
# 41        BLYTHE RIVERSIDE CO ARPT        6 33.61700 -114.71700
# 42                TWENTYNINE PALMS        0 34.30000 -116.16700
# 43                SAN JOSE INTL AP        4 37.36700 -121.93300
# 44                        INYOKERN        5 35.66700 -117.83300
# 45                PALMDALE AIRPORT        5 34.63300 -118.08300
# 46                       MARCH AFB        0 33.90000 -117.25000
# 47                SAN LUIS CO RGNL        4 35.23300 -120.63300
# 48       SAN DIEGO LINDBERGH FIELD        2 32.73300 -117.16700
# 49      LANCASTER GEN WM FOX FIELD        5 34.73300 -118.21700
# ..                             ...      ...      ...        ...
# 55                    LOS ALAMITOS        2 33.78300 -118.05000
# 56             OCEANSIDE MUNICIPAL        2 33.21700 -117.35000
# 57         SANTA MARIA PUBLIC ARPT        4 34.91700 -120.46700
# 58      SANTA BARBARA MUNICIPAL AP        3 34.43300 -119.85000
# 59   BURBANK-GLENDALE-PASSADENA AP        2 34.20000 -118.35000
# 60             FULLERTON MUNICIPAL        2 33.86700 -117.98300
# 61    SANTA CATALINA CATALINA ARPT        2 33.40000 -118.41700
# 62                  OXNARD AIRPORT        3 34.20000 -119.20000
# 63   LOS ANGELES DOWNTOWN USC CAMP        2 34.05000 -118.23300
# 64         TORRANCE MUNICIPAL ARPT        2 33.80000 -118.33300
# 65               SANTA ROSA (AWOS)        4 38.51700 -122.81700
# 66                  BISHOP AIRPORT        1 37.36700 -118.35000
# 67                  BLUE CANYON AP        5 39.30000 -120.71700
# 68                    MOUNT SHASTA        5 41.33300 -122.33300
# 69             JACK NORTHROP FLD H        2 33.91700 -118.33300
# 70                        OROVILLE        3 39.50000 -121.61700
# 71                   LOMPOC (AWOS)        4 34.66700 -120.46700
# 72                HAYWARD AIR TERM        4 37.66700 -122.11700
# 73    CHULA VISTA BROWN FIELD NAAS        2 32.58300 -116.98300
# 74           LOS ANGELES INTL ARPT        2 33.93300 -118.40000
# 75                   POINT MUGU NF        3 34.11700 -119.11700
# 76                        IMPERIAL        6 32.83300 -115.58300
# 77         PALM SPRINGS THERMAL AP        0 33.63300 -116.16700
# 78      STOCKTON METROPOLITAN ARPT        3 37.90000 -121.23300
# 79      SAN DIEGO NORTH ISLAND NAS        2 32.70000 -117.20000
# 80                  CHINA LAKE NAF        5 35.68300 -117.68300
# 81       OAKLAND METROPOLITAN ARPT        4 37.71700 -122.21700
# 82                NAPA CO. AIRPORT        4 38.21700 -122.28300
# 83             CAMP PENDLETON MCAS        2 33.30000 -117.35000
# 84                 NEEDLES AIRPORT        0 34.76700 -114.61700
# 85                   TRUCKEE-TAHOE        1 39.31700 -120.13300
# 86              PORTERVILLE (AWOS)        3 36.03300 -119.06700
# 87                     ALAMEDA NAS        4 37.73300 -122.31700
# 88      DAGGETT BARSTOW-DAGGETT AP        5 34.85000 -116.80000
# 89                         YUBA CO        3 39.10000 -121.56700
# 90                      CASTLE AFB        3 37.38300 -120.56700
# 91               SANTA MONICA MUNI        2 34.01700 -118.45000
# 92                          RAMONA        2 33.03300 -116.91700
# 93     MONTAGUE SISKIYOU COUNTY AP        5 41.78300 -122.46700
# 94          MODESTO CITY-COUNTY AP        3 37.63300 -120.95000
# 95            CRESCENT CITY FAA AI        4 41.78300 -124.23300
# 96         SANTA ANA JOHN WAYNE AP        2 33.68300 -117.86700
# 97   IMPERIAL BEACH REAM FIELD NAS        2 32.56700 -117.11700
# 98              UKIAH MUNICIPAL AP        4 39.13300 -123.20000
# 99                  RIVERSIDE MUNI        0 33.95000 -117.45000
# 100                  EL MONTE EMSU        2 34.08300 -118.03300
# 101                   MONTEREY NAF        4 36.60000 -121.86700
# 102                      BEALE AFB        3 39.13300 -121.43300
# 103            VISALIA MUNI (AWOS)        3 36.31700 -119.40000
# 104      BAKERSFIELD MEADOWS FIELD        3 35.43300 -119.05000
#
#      Centroid_Dist    USAF  CLASS
# 0          3.59682  722927      2
# 1          5.34634  724830      1
# 2          5.09995  690160      3
# 3          3.16284  724833      3
# 4         12.86466  725920      1
# 5          4.77649  723898      3
# 6          7.09038  722899      3
# 7          3.48593  747020      2
# 8          6.49092  723965      2
# 9          3.64849  723890      1
# 10         3.55625  724839      2
# 11         2.74422  745160      2
# 12         6.59526  723926      3
# 13         6.19466  722886      2
# 14         2.18726  722867      3
# 15         2.49561  722953      3
# 16         9.29602  722910      3
# 17         4.39246  722925      3
# 18         3.88521  722970      1
# 19         3.81926  722868      2
# 20         8.93015  723830      3
# 21         2.99664  724917      2
# 22         1.77685  722810      3
# 23         2.42396  724936      2
# 24         1.03368  725847      2
# 25         4.50650  724940      1
# 26         8.33440  722866      3
# 27         8.72676  725945      1
# 28        12.75221  725910      2
# 29        12.47133  724973      3
# 30         3.26689  724836      3
# 31         8.23364  746110      3
# 32         2.68344  745046      3
# 33         3.11260  724927      2
# 34         4.37843  723930      3
# 35         5.45006  722930      2
# 36         6.47009  722903      2
# 37         4.60602  724815      2
# 38         5.33051  725958      2
# 39         2.65624  724828      3
# 40         2.29502  745058      3
# 41         3.80076  747188      2
# 42         4.90270  690150      2
# 43         1.73739  724945      2
# 44         8.39814  723826      3
# 45         3.57170  723820      2
# 46         5.31589  722860      2
# 47         4.04779  722897      2
# 48         6.38647  722900      1
# 49         4.79606  723816      2
# ..             ...     ...    ...
# 55         3.44462  722975      3
# 56         3.25594  722934      3
# 57         6.58018  723940      1
# 58         6.57764  723925      1
# 59         6.29658  722880      2
# 60         2.96771  722976      2
# 61         3.39100  722920      3
# 62         6.36396  723927      2
# 63         4.26389  722874      3
# 64         5.80789  722955      3
# 65         4.26107  724957      2
# 66         4.23301  724800      2
# 67         8.13624  725845      2
# 68         8.15191  725957      3
# 69         4.61676  722956      2
# 70         5.08922  745048      3
# 71         4.98476  722895      3
# 72         2.41581  724935      2
# 73         6.62165  722904      2
# 74         4.58456  722950      1
# 75         6.79365  723910      2
# 76         2.10691  747185      2
# 77         4.53541  747187      2
# 78         4.10703  724920      2
# 79         6.28923  722906      2
# 80         9.72996  746120      2
# 81         3.45082  724930      2
# 82         5.37849  724955      2
# 83         3.25965  722926      2
# 84        10.50223  723805      2
# 85         2.87849  725846      2
# 86         4.85295  723895      3
# 87         3.73532  745060      3
# 88         6.56409  723815      1
# 89         3.49908  724838      2
# 90         4.53169  724810      3
# 91         4.57113  722885      2
# 92         8.01015  745056      3
# 93         8.61838  725955      2
# 94         2.33074  724926      2
# 95         9.43179  725946      2
# 96         2.75288  722977      2
# 97         7.01294  722909      3
# 98         4.17465  725905      2
# 99         4.38576  722869      2
# 100        4.64097  747040      3
# 101        3.92965  724915      2
# 102        3.45471  724837      2
# 103        4.43614  723896      2
# 104        5.26252  723840      1
#
# [105 rows x 7 columns]

# %%
df = stations.sort_values(['Cluster', 'CLASS', 'Centroid_Dist'])

# %%
df
# Out:
#                            Station  Cluster      Lat       Long  \
# 27                  ARCATA AIRPORT        0 40.98300 -124.10000
# 95            CRESCENT CITY FAA AI        0 41.78300 -124.23300
# 101                   MONTEREY NAF        0 36.60000 -121.86700
# 88      DAGGETT BARSTOW-DAGGETT AP        1 34.85000 -116.80000
# 45                PALMDALE AIRPORT        1 34.63300 -118.08300
# 50                     EDWARDS AFB        1 34.90000 -117.86700
# 49      LANCASTER GEN WM FOX FIELD        1 34.73300 -118.21700
# 15                          MOJAVE        1 35.06700 -118.15000
# 31              BICYCLE LAKE (AAF)        1 35.28300 -116.61700
# 20                        SANDBERG        1 34.75000 -118.71700
# 18        LONG BEACH DAUGHERTY FLD        2 33.83300 -118.16700
# 74           LOS ANGELES INTL ARPT        2 33.93300 -118.40000
# 60             FULLERTON MUNICIPAL        2 33.86700 -117.98300
# 96         SANTA ANA JOHN WAYNE AP        2 33.68300 -117.86700
# 69             JACK NORTHROP FLD H        2 33.91700 -118.33300
# 91               SANTA MONICA MUNI        2 34.01700 -118.45000
# 55                    LOS ALAMITOS        2 33.78300 -118.05000
# 63   LOS ANGELES DOWNTOWN USC CAMP        2 34.05000 -118.23300
# 61    SANTA CATALINA CATALINA ARPT        2 33.40000 -118.41700
# 17            SAN CLEMENTE IS NAAS        2 33.01700 -118.58300
# 100                  EL MONTE EMSU        2 34.08300 -118.03300
# 64         TORRANCE MUNICIPAL ARPT        2 33.80000 -118.33300
# 2                      TUSTIN MCAF        2 33.70000 -117.83300
# 54                    EL TORO MCAS        2 33.66700 -117.73300
# 1        SACRAMENTO EXECUTIVE ARPT        3 38.50000 -121.50000
# 37             MERCED/MACREADY FLD        3 37.28300 -120.51700
# 7               LEMOORE REEVES NAS        3 36.33300 -119.95000
# 78      STOCKTON METROPOLITAN ARPT        3 37.90000 -121.23300
# 90                      CASTLE AFB        3 37.38300 -120.56700
# 5         HANFORD MUNI ARPT [ISIS]        3 36.31000 -119.63000
# 76                        IMPERIAL        4 32.83300 -115.58300
# 41        BLYTHE RIVERSIDE CO ARPT        4 33.61700 -114.71700
# 22                             NAF        4 32.81700 -115.68300
# 99                  RIVERSIDE MUNI        5 33.95000 -117.45000
# 46                       MARCH AFB        5 33.90000 -117.25000
# 51                         ONTARIO        5 34.06700 -117.65000
# 14                    BEAUMONT 1 E        5 33.93300 -116.96700
# 6                    CHINO AIRPORT        5 33.96700 -117.63300
# 26             NORTON AFB/SAN BERN        5 34.10000 -117.23300
# 24                SOUTH LAKE TAHOE        6 38.90000 -120.00000
# 85                   TRUCKEE-TAHOE        6 39.31700 -120.13300
# 66                  BISHOP AIRPORT        6 37.36700 -118.35000
# 38                         ALTURAS        6 41.50000 -120.53300
# 25           SAN FRANCISCO INTL AP        7 37.61700 -122.40000
# 72                HAYWARD AIR TERM        7 37.66700 -122.11700
# 43                SAN JOSE INTL AP        7 37.36700 -121.93300
# 23   CONCORD CONCORD-BUCHANAN FIEL        7 38.00000 -122.05000
# 81       OAKLAND METROPOLITAN ARPT        7 37.71700 -122.21700
# 11                TRAVIS FIELD AFB        7 38.26700 -121.93300
# 33             LIVERMORE MUNICIPAL        7 37.70000 -121.81700
# ..                             ...      ...      ...        ...
# 87                     ALAMEDA NAS        7 37.73300 -122.31700
# 80                  CHINA LAKE NAF        8 35.68300 -117.68300
# 44                        INYOKERN        8 35.66700 -117.83300
# 4           REDDING MUNICIPAL ARPT        9 40.51700 -122.31700
# 28        RED BLUFF MUNICIPAL ARPT        9 40.15000 -122.25000
# 29                 CHICO MUNICIPAL        9 39.80000 -121.85000
# 57         SANTA MARIA PUBLIC ARPT       10 34.91700 -120.46700
# 47                SAN LUIS CO RGNL       10 35.23300 -120.63300
# 21            SALINAS MUNICIPAL AP       10 36.66700 -121.60000
# 8       PASO ROBLES MUNICIPAL ARPT       10 35.66700 -120.63300
# 34                  VANDENBERG AFB       10 34.75000 -120.58300
# 53                VANDENBERG RANGE       10 34.71700 -120.56700
# 71                   LOMPOC (AWOS)       10 34.66700 -120.46700
# 40                     WATSONVILLE       10 36.93300 -121.78300
# 48       SAN DIEGO LINDBERGH FIELD       11 32.73300 -117.16700
# 35           SAN DIEGO MIRAMAR NAS       11 32.86700 -117.13300
# 0                 CARLSBAD/PALOMAR       11 33.13300 -117.28300
# 36             SAN DIEGO/MONTGOMER       11 32.81700 -117.13300
# 83             CAMP PENDLETON MCAS       11 33.30000 -117.35000
# 73    CHULA VISTA BROWN FIELD NAAS       11 32.58300 -116.98300
# 79      SAN DIEGO NORTH ISLAND NAS       11 32.70000 -117.20000
# 56             OCEANSIDE MUNICIPAL       11 33.21700 -117.35000
# 97   IMPERIAL BEACH REAM FIELD NAS       11 32.56700 -117.11700
# 92                          RAMONA       11 33.03300 -116.91700
# 58      SANTA BARBARA MUNICIPAL AP       12 34.43300 -119.85000
# 75                   POINT MUGU NF       12 34.11700 -119.11700
# 62                  OXNARD AIRPORT       12 34.20000 -119.20000
# 13                VAN NUYS AIRPORT       12 34.21700 -118.48300
# 59   BURBANK-GLENDALE-PASSADENA AP       12 34.20000 -118.35000
# 12                CAMARILLO (AWOS)       12 34.21700 -119.08300
# 16             SAN NICHOLAS ISLAND       12 33.25000 -119.45000
# 9          FRESNO YOSEMITE INTL AP       13 36.78300 -119.71700
# 104      BAKERSFIELD MEADOWS FIELD       13 35.43300 -119.05000
# 102                      BEALE AFB       13 39.13300 -121.43300
# 94          MODESTO CITY-COUNTY AP       13 37.63300 -120.95000
# 89                         YUBA CO       13 39.10000 -121.56700
# 10      SACRAMENTO METROPOLITAN AP       13 38.70000 -121.58300
# 103            VISALIA MUNI (AWOS)       13 36.31700 -119.40000
# 3                     MATHER FIELD       13 38.55000 -121.30000
# 30                   MCCLELLAN AFB       13 38.66700 -121.40000
# 32                          MADERA       13 36.98300 -120.11700
# 70                        OROVILLE       13 39.50000 -121.61700
# 86              PORTERVILLE (AWOS)       13 36.03300 -119.06700
# 42                TWENTYNINE PALMS       14 34.30000 -116.16700
# 77         PALM SPRINGS THERMAL AP       14 33.63300 -116.16700
# 19               PALM SPRINGS INTL       14 33.83300 -116.50000
# 84                 NEEDLES AIRPORT       14 34.76700 -114.61700
# 93     MONTAGUE SISKIYOU COUNTY AP       15 41.78300 -122.46700
# 67                  BLUE CANYON AP       15 39.30000 -120.71700
# 68                    MOUNT SHASTA       15 41.33300 -122.33300
#
#      Centroid_Dist    USAF  CLASS
# 27         1.99010  725945      1
# 95         2.83127  725946      2
# 101        4.69712  724915      2
# 88         4.63014  723815      1
# 45         2.05264  723820      2
# 50         2.14745  723810      2
# 49         2.36621  723816      2
# 15         3.22195  722953      3
# 31         5.33533  746110      3
# 20         6.45239  723830      3
# 18         1.90124  722970      1
# 74         2.73493  722950      1
# 60         1.25739  722976      2
# 96         1.57782  722977      2
# 69         2.45240  722956      2
# 91         2.95392  722885      2
# 55         1.64567  722975      3
# 63         3.12026  722874      3
# 61         3.63773  722920      3
# 17         3.66030  722925      3
# 100        4.02571  747040      3
# 64         4.36294  722955      3
# 2          4.67815  690160      3
# 54         4.96732  690140      3
# 1          3.01334  724830      1
# 37         1.36317  724815      2
# 7          1.98709  747020      2
# 78         2.28605  724920      2
# 90         1.15789  724810      3
# 5          3.76999  723898      3
# 76         2.10691  747185      2
# 41         3.80076  747188      2
# 22         1.77685  722810      3
# 99         1.14486  722869      2
# 46         3.85713  722860      2
# 51         3.68217  722865      3
# 14         3.94970  722867      3
# 6          4.28830  722899      3
# 26         8.55390  722866      3
# 24         1.03368  725847      2
# 85         2.87849  725846      2
# 66         4.23301  724800      2
# 38         5.33051  725958      2
# 25         3.99773  724940      1
# 72         0.64073  724935      2
# 43         1.46551  724945      2
# 23         1.51196  724936      2
# 81         1.63908  724930      2
# 11         2.50892  745160      2
# 33         3.22981  724927      2
# ..             ...     ...    ...
# 87         3.34352  745060      3
# 80         0.74062  746120      2
# 44         0.74062  723826      3
# 4          2.85041  725920      1
# 28         1.46684  725910      2
# 29         1.79434  724973      3
# 57         4.01424  723940      1
# 47         1.06100  722897      2
# 21         2.79322  724917      2
# 8          4.55058  723965      2
# 34         1.44308  723930      3
# 53         1.48837  723935      3
# 71         2.30686  722895      3
# 40         3.66547  745058      3
# 48         3.27134  722900      1
# 35         1.62981  722930      2
# 0          2.54477  722927      2
# 36         3.22364  722903      2
# 83         3.22572  722926      2
# 73         3.22669  722904      2
# 79         3.25689  722906      2
# 56         2.89449  722934      3
# 97         3.81126  722909      3
# 92         6.07729  745056      3
# 58         3.14307  723925      1
# 75         0.54406  723910      2
# 62         1.26923  723927      2
# 13         2.81438  722886      2
# 59         3.01950  722880      2
# 12         0.78062  723926      3
# 16         3.44585  722910      3
# 9          2.49245  723890      1
# 104        5.67599  723840      1
# 102        2.03940  724837      2
# 94         2.47035  724926      2
# 89         3.03298  724838      2
# 10         3.25440  724839      2
# 103        3.96564  723896      2
# 3          2.03201  724833      3
# 30         2.09733  724836      3
# 32         2.23402  745046      3
# 70         3.89564  745048      3
# 86         4.30701  723895      3
# 42         1.81065  690150      2
# 77         2.85074  747187      2
# 19         3.53096  722868      2
# 84         5.34391  723805      2
# 93         1.76688  725955      2
# 67         4.05319  725845      2
# 68         2.89364  725957      3
#
# [105 rows x 7 columns]

# %%
selected_station = pd.DataFrame()
for i in list(sorted(stations.Cluster.unique())):
    selected_station = selected_station.append(df[df.Cluster == i].head(1))

# %%
selected_station.rename({'Station':'STATION',
                         'Lat':'latitude',
                         'Long':'longitude'}, axis=1, inplace = True)
selected_station
# Out:
#                         STATION  Cluster  latitude  longitude  Centroid_Dist  \
# 27               ARCATA AIRPORT        0  40.98300 -124.10000        1.99010
# 88   DAGGETT BARSTOW-DAGGETT AP        1  34.85000 -116.80000        4.63014
# 18     LONG BEACH DAUGHERTY FLD        2  33.83300 -118.16700        1.90124
# 1     SACRAMENTO EXECUTIVE ARPT        3  38.50000 -121.50000        3.01334
# 76                     IMPERIAL        4  32.83300 -115.58300        2.10691
# 99               RIVERSIDE MUNI        5  33.95000 -117.45000        1.14486
# 24             SOUTH LAKE TAHOE        6  38.90000 -120.00000        1.03368
# 25        SAN FRANCISCO INTL AP        7  37.61700 -122.40000        3.99773
# 80               CHINA LAKE NAF        8  35.68300 -117.68300        0.74062
# 4        REDDING MUNICIPAL ARPT        9  40.51700 -122.31700        2.85041
# 57      SANTA MARIA PUBLIC ARPT       10  34.91700 -120.46700        4.01424
# 48    SAN DIEGO LINDBERGH FIELD       11  32.73300 -117.16700        3.27134
# 58   SANTA BARBARA MUNICIPAL AP       12  34.43300 -119.85000        3.14307
# 9       FRESNO YOSEMITE INTL AP       13  36.78300 -119.71700        2.49245
# 42             TWENTYNINE PALMS       14  34.30000 -116.16700        1.81065
# 93  MONTAGUE SISKIYOU COUNTY AP       15  41.78300 -122.46700        1.76688
#
#       USAF  CLASS
# 27  725945      1
# 88  723815      1
# 18  722970      1
# 1   724830      1
# 76  747185      2
# 99  722869      2
# 24  725847      2
# 25  724940      1
# 80  746120      2
# 4   725920      1
# 57  723940      1
# 48  722900      1
# 58  723925      1
# 9   723890      1
# 42  690150      2
# 93  725955      2

# %%
selected_station = selected_station.reset_index()
selected_station.drop('index', axis = 1, inplace =True)

# %%
selected_station['CZ']= pd.Series(['Arcata',
                                   'Palmdale', 
                                   'Torrance',
                                   'Sacramento',
                                   'Palm Spring-Intl',
                                   'Burbank-Glendale',
                                   'Blue Canyon',
                                   'Oakland',
                                   'China Lake',
                                   'Santa Rosa',
                                   'Santa Maria',
                                   'San Diego-Lindbergh',
                                   'Santa Barbaba',
                                   'Fresno',
                                   'Palm Spring',
                                   'Red Bluff'], index = selected_station.index)

# %%
selected_station
# Out:
#                         STATION  Cluster  latitude  longitude  Centroid_Dist  \
# 0                ARCATA AIRPORT        0  40.98300 -124.10000        1.99010
# 1    DAGGETT BARSTOW-DAGGETT AP        1  34.85000 -116.80000        4.63014
# 2      LONG BEACH DAUGHERTY FLD        2  33.83300 -118.16700        1.90124
# 3     SACRAMENTO EXECUTIVE ARPT        3  38.50000 -121.50000        3.01334
# 4                      IMPERIAL        4  32.83300 -115.58300        2.10691
# 5                RIVERSIDE MUNI        5  33.95000 -117.45000        1.14486
# 6              SOUTH LAKE TAHOE        6  38.90000 -120.00000        1.03368
# 7         SAN FRANCISCO INTL AP        7  37.61700 -122.40000        3.99773
# 8                CHINA LAKE NAF        8  35.68300 -117.68300        0.74062
# 9        REDDING MUNICIPAL ARPT        9  40.51700 -122.31700        2.85041
# 10      SANTA MARIA PUBLIC ARPT       10  34.91700 -120.46700        4.01424
# 11    SAN DIEGO LINDBERGH FIELD       11  32.73300 -117.16700        3.27134
# 12   SANTA BARBARA MUNICIPAL AP       12  34.43300 -119.85000        3.14307
# 13      FRESNO YOSEMITE INTL AP       13  36.78300 -119.71700        2.49245
# 14             TWENTYNINE PALMS       14  34.30000 -116.16700        1.81065
# 15  MONTAGUE SISKIYOU COUNTY AP       15  41.78300 -122.46700        1.76688
#
#       USAF  CLASS                   CZ
# 0   725945      1               Arcata
# 1   723815      1             Palmdale
# 2   722970      1             Torrance
# 3   724830      1           Sacramento
# 4   747185      2     Palm Spring-Intl
# 5   722869      2     Burbank-Glendale
# 6   725847      2          Blue Canyon
# 7   724940      1              Oakland
# 8   746120      2           China Lake
# 9   725920      1           Santa Rosa
# 10  723940      1          Santa Maria
# 11  722900      1  San Diego-Lindbergh
# 12  723925      1        Santa Barbaba
# 13  723890      1               Fresno
# 14  690150      2          Palm Spring
# 15  725955      2            Red Bluff

# %%
selected_station.to_csv('selected_stations.csv')

# %%
list(selected_station.USAF)
# Out:
# [725945,
#  723815,
#  722970,
#  724830,
#  747185,
#  722869,
#  725847,
#  724940,
#  746120,
#  725920,
#  723940,
#  722900,
#  723925,
#  723890,
#  690150,
#  725955]

# %%
len(list(selected_station.USAF))
# Out:
# 16

# %%
import glob

for i in list(selected_station.USAF):
    print "process station ", i
    out = str(i) + '.csv'
    allFiles = glob.glob('nsrdb_solar/' + str(i) + '/*.csv')
    data_all = pd.DataFrame()
    list_ = []
    for file_ in allFiles:
        df = pd.read_csv(file_,index_col=None, header=0)
        list_.append(df)
    data_all = pd.concat(list_)
    data_all.to_csv(out)
# Out:
# process station  725945
# process station  723815
# process station  722970
# process station  724830
# process station  747185
# process station  722869
# process station  725847
# process station  724940
# process station  746120
# process station  725920
# process station  723940
# process station  722900
# process station  723925
# process station  723890
# process station  690150
# process station  725955

# %%
selected_station.columns
# Out:
# Index([u'STATION', u'Cluster', u'latitude', u'longitude', u'Centroid_Dist',
#        u'USAF', u'CLASS', u'CZ'],
#       dtype='object')
